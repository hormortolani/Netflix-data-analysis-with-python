# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # import dataset from the local directory

# %%
dataset = pd.read_csv(r"C:\Users\HP\Desktop\data\netflix_titles.csv")

# %%
dataset.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# # Getting some basics information about the dataset

# %%
##to show the number of row and column in a dataset 
dataset.shape
# Out:
# (8807, 12)

# %%
##to show the total number of element in a dataset
dataset.size
# Out:
# 105684

# %%
##columns is use to show each columns name
dataset.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
###to show the datatypes of each columns
dataset.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
###use to show indexes, datatypes of each coulmns
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# # To check any duplicate record in the dataset

# %%
##to check row and detect the duplicate
dataset[dataset.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# # To check any null-values in the dataset

# %%
##check the null-values
dataset.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
##to show the total number of null values in each columns
dataset.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
##viewing the null value using seaborn
sns.heatmap(dataset.isnull())
# Out:
# <Axes: >

# %% [markdown]
# #                                       Exploratory Data AnalysAnalysis

# %% [raw]
# checking the year in which highest number of the TV shows and movies were released

# %%
##to check the datatypes
dataset.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
##to check the datetime

dataset['data_date'] = pd.to_datetime(dataset['date_added'])

# %%
dataset.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
dataset.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# data_date       datetime64[ns]
# dtype: object

# %%
### To count the occurance of all individual years in date columns

dataset['data_date'].dt.year.value_counts()
# Out:
# 2019.0    2016
# 2020.0    1879
# 2018.0    1649
# 2021.0    1498
# 2017.0    1188
# 2016.0     429
# 2015.0      82
# 2014.0      24
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: data_date, dtype: int64

# %%
dataset['data_date'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [raw]
#  checking the number of movies and TV shows are in the dataset

# %%
dataset.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
### to group all uniques items of a column and show their count

dataset.groupby('type').type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
sns.set(style="darkgrid")
ax = sns.countplot(x="type", data=dataset, palette="Set2")

# %% [raw]
# To show all TV show released in year 2021

# %%
##create a new year column which will consider only year

dataset['year'] = dataset['data_date'].dt.year

# %%
dataset.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
filtered_data = dataset[(dataset['type'] == 'TV Show') & (dataset['year'] == 2021)]
filtered_data.head(3)
# Out:
#   show_id     type                  title         director  \
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                NaN           NaN
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
#
# ...

# %% [raw]
# Titles of the movies that were released only in Nigeria

# %%
dataset [(dataset['type'] == 'Movie') & (dataset['country'] == 'Nigeria')]
# Out:
#      show_id   type                                   title  \
# 73       s74  Movie                            King of Boys
# 84       s85  Movie                    Omo Ghetto: the Saga
# 281     s282  Movie                           Brother Jekwu
# 298     s299  Movie                            Quam's Money
# 306     s307  Movie                                     '76
# ...      ...    ...                                     ...
# 7875   s7876  Movie                       Road to Yesterday
# 8227   s8228  Movie                              The Bridge
# 8241   s8242  Movie                                 The CEO
# 8297   s8298  Movie                The Figurine (Araromire)
# 8556   s8557  Movie  The Wedding Party 2: Destination Dubai
#
#                         director  \
# 73                  Kemi Adetiba
# 84    JJC Skillz, Funke Akindele
# 281              Charles Uwagbai
# 298                 Kayode Kasum
# 306                   Izu Ojukwu
# ...                          ...
# ...

# %%
###To show the titles only


dataset [(dataset['type'] == 'Movie') & (dataset['country'] == 'Nigeria')] ['title']
# Out:
# 73                                King of Boys
# 84                        Omo Ghetto: the Saga
# 281                              Brother Jekwu
# 298                               Quam's Money
# 306                                        '76
#                          ...
# 7875                         Road to Yesterday
# 8227                                The Bridge
# 8241                                   The CEO
# 8297                  The Figurine (Araromire)
# 8556    The Wedding Party 2: Destination Dubai
# Name: title, Length: 86, dtype: object

# %% [raw]
# Top 5 directors who gave the highest number of movies and TV Show

# %%
dataset['director'].value_counts().head(5)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Name: director, dtype: int64

# %% [raw]
# Showing the record where type is "Movie" and listed_in is "Comedies" OR country in Nigeria
#
# Using AND OR Operators

# %%
dataset.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  data_date    year
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0

# %%
dataset[(dataset['type'] == 'Movie') & (dataset['listed_in'] == 'Comedies')]
# Out:
#      show_id   type                                   title  \
# 27       s28  Movie                               Grown Ups
# 152     s153  Movie           Janoskians: Untold and Untrue
# 182     s183  Movie             Welcome Home Roscoe Jenkins
# 342     s343  Movie                             Major Payne
# 348     s349  Movie                                    Poms
# ...      ...    ...                                     ...
# 8420   s8421  Movie              The Men Who Stare at Goats
# 8433   s8434  Movie  The Naked Gun 2 1/2: The Smell of Fear
# 8536   s8537  Movie                       The Trip to Spain
# 8608   s8609  Movie                        Total Frat Movie
# 8730   s8731  Movie                       Where's the Money
#
#                   director                                               cast  \
# 27            Dennis Dugan  Adam Sandler, Kevin James, Chris Rock, David S...
# 152           Brett Weiner  Jai Brooks, Luke Brooks, James Yammouni, Danie...
# ...

# %%
##using the OR operators

dataset[(dataset['type'] == 'Movie') & (dataset['listed_in'] == 'Comedies') | (dataset['country']=="Nigeria")]
# Out:
#      show_id     type                                   title  \
# 27       s28    Movie                               Grown Ups
# 49       s50  TV Show                       Castle and Castle
# 73       s74    Movie                            King of Boys
# 84       s85    Movie                    Omo Ghetto: the Saga
# 152     s153    Movie           Janoskians: Untold and Untrue
# ...      ...      ...                                     ...
# 8433   s8434    Movie  The Naked Gun 2 1/2: The Smell of Fear
# 8536   s8537    Movie                       The Trip to Spain
# 8556   s8557    Movie  The Wedding Party 2: Destination Dubai
# 8608   s8609    Movie                        Total Frat Movie
# 8730   s8731    Movie                       Where's the Money
#
#                         director  \
# 27                  Dennis Dugan
# 49                           NaN
# 73                  Kemi Adetiba
# 84    JJC Skillz, Funke Akindele
# 152                 Brett Weiner
# ...

# %% [raw]
# What are the different ratings in Netflix

# %%
plt.figure(figsize=(12,10))
sns.set(style="darkgrid")
ax = sns.countplot(x="rating", data=dataset, palette="Set2", order=dataset['rating'].value_counts().index[0:15])

# %%
### to show the unique values in the column

dataset['rating'].nunique()
# Out:
# 17

# %%
#### Numbers of TV Show with 'TV_PG' rating in Nigeria


dataset [(dataset['type'] == 'Movie') & (dataset['rating'] == 'TV-14')].shape
# Out:
# (1427, 14)

# %%
dataset [(dataset['type'] == 'TV Show') & (dataset['rating'] == 'TV-14') & (dataset['country']=='Nigeria')]
# Out:
#      show_id     type                  title director  \
# 2148   s2149  TV Show           The Governor      NaN
# 2938   s2939  TV Show      Fifty: The Series      NaN
# 2992   s2993  TV Show  Sons of the Caliphate      NaN
#
#                                                    cast  country  \
# 2148  Caroline Chikezie, Bimbo Manuel, Lord Frank, E...  Nigeria
# 2938  Ireti Doyle, Keira Hewatch, Dakore Akande, Omo...  Nigeria
# 2992  Yakubu Mohammed, Paul Sambo, Mofe Duncan, Nita...  Nigeria
#
#             date_added  release_year rating   duration  \
# 2148    August 8, 2020          2016  TV-14   1 Season
# 2938  February 7, 2020          2018  TV-14  2 Seasons
# 2992  January 24, 2020          2017  TV-14  2 Seasons
#
#                                               listed_in  \
# 2148                  International TV Shows, TV Dramas
# 2938  International TV Shows, Romantic TV Shows, TV ...
# 2992                  International TV Shows, TV Dramas
#
# ...

# %%
####How many movies got the "PG-13", before year 2020


dataset[(dataset['type'] == "Movie") & (dataset['rating'] == "PG-13") & (dataset['year']<2020)]
# Out:
#      show_id   type                           title            director  \
# 3080   s3081  Movie  Benchwarmers 2: Breaking Balls       Jon Rosenbaum
# 3099   s3100  Movie            Grand-Daddy Day Care          Ron Oliver
# 3102   s3103  Movie                      Sweetheart        J.D. Dillard
# 3116   s3117  Movie                   The Two Popes  Fernando Meirelles
# 3164   s3165  Movie               Nothing to Lose 2  Alexandre Avancini
# ...      ...    ...                             ...                 ...
# 8696   s8697  Movie                       War Horse    Steven Spielberg
# 8757   s8758  Movie              World Trade Center        Oliver Stone
# 8766   s8767  Movie                             XXx           Rob Cohen
# 8767   s8768  Movie         XXX: State of the Union        Lee Tamahori
# 8782   s8783  Movie                     Yoga Hosers         Kevin Smith
#
#                                                    cast  \
# ...

# %% [raw]
# Checking maximum of TV show and movies in Netflix

# %%
###checking the unique value

dataset.duration.unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
dataset.duration.dtypes
# Out:
# dtype('O')

# %%
dataset[['minutes', 'Unit']] = dataset['duration'].str.split(' ',expand = True)
dataset.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
dataset['minutes'] = pd.to_numeric(dataset['minutes'], errors='coerce')

# %%
##To check the max mins

dataset['minutes'].max()
# Out:
# 312.0

# %%
##To check the min mins

dataset['minutes'].min()
# Out:
# 1.0

# %%
##To check the mean mins

dataset['minutes'].mean()
# Out:
# 69.84688777828259

# %% [raw]
# Country with highest number of TV_show

# %%
dataset_tv_show = dataset[dataset['type'] == "TV Show"]
dataset_tv_show.head(3)
# Out:
#   show_id     type                  title         director  \
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                NaN           NaN
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
#
# ...

# %%
###TV show per country


dataset_tv_show.country.value_counts()
# Out:
# United States                                    760
# United Kingdom                                   213
# Japan                                            169
# South Korea                                      158
# India                                             79
#                                                 ...
# Belarus                                            1
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# Australia, New Zealand, United States              1
# United States, France, South Korea, Indonesia      1
# Name: country, Length: 196, dtype: int64

# %%
dataset_tv_show.country.value_counts().head(1)
# Out:
# United States    760
# Name: country, dtype: int64

# %% [raw]
# Country with highest number of Movies

# %%
dataset_movie = dataset[dataset['type'] == "Movie"]
dataset_movie.head(3)

dataset_movie.country.value_counts().head(1)
# Out:
# United States    2058
# Name: country, dtype: int64

# %% [raw]
# Sorting Dataset by year

# %%
###how to sort dataset by year

dataset.sort_values(by = 'year')
# Out:
#      show_id     type                         title              director  \
# 5957   s5958    Movie          To and From New York  Sorin Dan Mihalcescu
# 6611   s6612  TV Show               Dinner for Five                   NaN
# 5956   s5957    Movie       Just Another Love Story          Ole Bornedal
# 5955   s5956    Movie                      Splatter             Joe Dante
# 7370   s7371    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 7196   s7197  TV Show                      Kikoriki                   NaN
# 7254   s7255  TV Show           La Familia P. Luche                   NaN
# 7406   s7407  TV Show                         Maron                   NaN
# 7847   s7848  TV Show                  Red vs. Blue                   NaN
# 8182   s8183  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    cast        country  \
# ...
